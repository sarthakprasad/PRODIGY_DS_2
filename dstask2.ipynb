# %% [markdown]
# # TASK 2
# # PERFORMING DATA CLEANING AND EXPLORATORY DATA ANALYSIS (EDA) ON TITANIC DATASET

# %% [markdown]
# # importing the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the dataset

# %%
dataset.isnull().sum()
# Out:
# PassengerId      1
# Married        863
# Survived         0
# Pclass           1
# Name             1
# Sex              1
# Age            178
# SibSp            1
# Parch            1
# Ticket           1
# Fare             1
# Cabin          688
# Embarked         3
# dtype: int64

# %%
dataset.tail(10)
# Out:
#      PassengerId Married  Survived  Pclass  \
# 882        883.0     NaN         0     3.0
# 883        884.0     NaN         0     2.0
# 884        885.0     NaN         0     3.0
# 885        886.0     NaN         0     3.0
# 886        887.0     NaN         0     2.0
# 887        888.0     NaN         1     1.0
# 888        889.0     NaN         0     3.0
# 889        890.0     NaN         1     1.0
# 890        891.0     NaN         0     3.0
# 891          NaN     NaN         0     NaN
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 882              Dahlberg, Miss. Gerda Ulrika  female  22.0    0.0    0.0
# 883             Banfield, Mr. Frederick James    male  28.0    0.0    0.0
# 884                    Sutehall, Mr. Henry Jr    male  25.0    0.0    0.0
# 885      Rice, Mrs. William (Margaret Norton)  female  39.0    0.0    5.0
# 886                     Montvila, Rev. Juozas    male  27.0    0.0    0.0
# 887              Graham, Miss. Margaret Edith  female  19.0    0.0    0.0
# 888  Johnston, Miss. Catherine Helen "Carrie"  female   NaN    1.0    2.0
# 889                     Behr, Mr. Karl Howell    male  26.0    0.0    0.0
# 890                       Dooley, Mr. Patrick    male  32.0    0.0    0.0
# 891                                       NaN     NaN   NaN    NaN    NaN
#
#                Ticket     Fare Cabin Embarked
# 882              7552  10.5167   NaN        S
# 883  C.A./SOTON 34068  10.5000   NaN        S
# 884   SOTON/OQ 392076   7.0500   NaN        S
# 885            382652  29.1250   NaN        Q
# 886            211536  13.0000   NaN        S
# 887            112053  30.0000   B42        S
# 888        W./C. 6607  23.4500   NaN        S
# 889            111369  30.0000  C148        C
# 890            370376   7.7500   NaN        Q
# 891               NaN      NaN   NaN      NaN

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  892.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383408    2.308642   29.678109    0.523008
# std     257.353842    0.486489    0.836071   14.525322    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    float64
#  1   Married      29 non-null     object
#  2   Survived     892 non-null    int64
#  3   Pclass       891 non-null    float64
#  4   Name         891 non-null    object
#  5   Sex          891 non-null    object
#  6   Age          714 non-null    float64
#  7   SibSp        891 non-null    float64
#  8   Parch        891 non-null    float64
#  9   Ticket       891 non-null    object
#  10  Fare         891 non-null    float64
#  11  Cabin        204 non-null    object
#  12  Embarked     889 non-null    object
# dtypes: float64(6), int64(1), object(6)
# memory usage: 90.7+ KB

# %% [markdown]
# # Checking for null values

# %%
dataset.isnull()
# Out:
#      PassengerId  Married  Survived  Pclass   Name    Sex    Age  SibSp  \
# 0          False    False     False   False  False  False  False  False
# 1          False    False     False   False  False  False  False  False
# 2          False    False     False   False  False  False  False  False
# 3          False    False     False   False  False  False  False  False
# 4          False    False     False   False  False  False  False  False
# ..           ...      ...       ...     ...    ...    ...    ...    ...
# 887        False     True     False   False  False  False  False  False
# 888        False     True     False   False  False  False   True  False
# 889        False     True     False   False  False  False  False  False
# 890        False     True     False   False  False  False  False  False
# 891         True     True     False    True   True   True   True   True
#
#      Parch  Ticket   Fare  Cabin  Embarked
# 0    False   False  False   True     False
# 1    False   False  False  False     False
# 2    False   False  False   True     False
# 3    False   False  False  False     False
# 4    False   False  False   True     False
# ..     ...     ...    ...    ...       ...
# 887  False   False  False  False     False
# 888  False   False  False   True     False
# 889  False   False  False  False     False
# 890  False   False  False   True     False
# 891   True    True   True   True      True
#
# [892 rows x 13 columns]

# %%
dataset.isnull().sum()
# Out:
# PassengerId      1
# Married        863
# Survived         0
# Pclass           1
# Name             1
# Sex              1
# Age            178
# SibSp            1
# Parch            1
# Ticket           1
# Fare             1
# Cabin          688
# Embarked         3
# dtype: int64

# %% [markdown]
# # dropping the null values

# %%
dataset.dropna(subset=["Embarked"],inplace=True)
dataset.dropna(subset=["Cabin"],inplace=True)
dataset.dropna(subset=["Age"],inplace=True)

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Married        175
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         0
# dtype: int64

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Married        175
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         0
# dtype: int64

# %%
dataset.head(10)
# Out:
#     PassengerId Married  Survived  Pclass  \
# 1           2.0     Yes         1     1.0
# 3           4.0     Yes         1     1.0
# 6           7.0     Yes         0     1.0
# 10         11.0     Yes         1     3.0
# 11         12.0     Yes         1     1.0
# 21         22.0      No         1     2.0
# 23         24.0      No         1     1.0
# 27         28.0      No         0     1.0
# 52         53.0     NaN         1     1.0
# 54         55.0     NaN         0     1.0
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 1                                    Amartya Raj    male  23.0    1.0    0.0
# 3   Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0    0.0
# 6                        McCarthy, Mr. Timothy J    male  54.0    0.0    0.0
# 10               Sandstrom, Miss. Marguerite Rut  female   4.0    1.0    1.0
# 11                      Bonnell, Miss. Elizabeth  female  58.0    0.0    0.0
# 21                         Beesley, Mr. Lawrence    male  34.0    0.0    0.0
# 23                  Sloper, Mr. William Thompson    male  28.0    0.0    0.0
# 27                Fortune, Mr. Charles Alexander    male  19.0    3.0    2.0
# 52      Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0    1.0    0.0
# 54                Ostby, Mr. Engelhart Cornelius    male  65.0    0.0    1.0
#
#       Ticket      Fare        Cabin Embarked
# 1   PC 17599   71.2833          C85        C
# 3     113803   53.1000         C123        S
# 6      17463   51.8625          E46        S
# 10   PP 9549   16.7000           G6        S
# 11    113783   26.5500         C103        S
# 21    248698   13.0000          D56        S
# 23    113788   35.5000           A6        S
# 27     19950  263.0000  C23 C25 C27        S
# 52  PC 17572   76.7292          D33        C
# 54    113509   61.9792          B30        C

# %%
dataset.dropna(subset=["Age"],inplace=True)

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset.duplicated()
# Out:
# 1      False
# 3      False
# 6      False
# 10     False
# 11     False
#        ...
# 871    False
# 872    False
# 879    False
# 887    False
# 889    False
# Length: 183, dtype: bool

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 183 entries, 1 to 889
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  183 non-null    float64
#  1   Married      8 non-null      object
#  2   Survived     183 non-null    int64
#  3   Pclass       183 non-null    float64
#  4   Name         183 non-null    object
#  5   Sex          183 non-null    object
#  6   Age          183 non-null    float64
#  7   SibSp        183 non-null    float64
#  8   Parch        183 non-null    float64
#  9   Ticket       183 non-null    object
#  10  Fare         183 non-null    float64
#  11  Cabin        183 non-null    object
#  12  Embarked     183 non-null    object
# dtypes: float64(6), int64(1), object(6)
# memory usage: 20.0+ KB

# %%
from sklearn.impute import SimpleImputer

# %%
dataset.select_dtypes(include="float64").columns
# Out:
# Index(['PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
dataset.select_dtypes(include="int64")
# Out:
#      Survived
# 1           1
# 3           1
# 6           0
# 10          1
# 11          1
# ..        ...
# 871         1
# 872         0
# 879         1
# 887         1
# 889         1
#
# [183 rows x 1 columns]

# %%
si = SimpleImputer(strategy="mean")
ar = si.fit_transform(dataset[['Age', 'Fare']])

# %%
dataset.select_dtypes(include="float64,").columns
# Out:
# Index(['PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
dataset.select_dtypes(include="int64").columns
# Out:
# Index(['Survived'], dtype='object')

# %%
si = SimpleImputer(strategy="mean")
ar = si.fit_transform(dataset[['Age', 'Fare']])

# %%
new_dataset = pd.DataFrame(ar,columns=dataset.select_dtypes(include="float64").columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 new_dataset = pd.DataFrame(ar,columns=dataset.select_dtypes(include="float64").columns)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:782, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     771         mgr = dict_to_mgr(
#     772             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     773             # attribute "name"
#    (...)
#     779             copy=_copy,
#     780         )
#     781     else:
# --> 782         mgr = ndarray_to_mgr(
#     783             data,
#     784             index,
#     785             columns,
#     786             dtype=dtype,
#     787             copy=copy,
#     788             typ=manager,
#     789         )
#     791 # For data is list-like, or Iterable (will consume into list)
#     792 elif is_list_like(data):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\construction.py:336, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     331 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     332 index, columns = _get_axes(
#     333     values.shape[0], values.shape[1], index=index, columns=columns
#     334 )
# --> 336 _check_values_indices_shape_match(values, index, columns)
#     338 if typ == "array":
#     339     if issubclass(values.dtype.type, str):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\construction.py:420, in _check_values_indices_shape_match(values, index, columns)
#     418 passed = values.shape
#     419 implied = (len(index), len(columns))
# --> 420 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (183, 2), indices imply (183, 6)

# %%
new_dataset.isnull().sum()
# Out:
# Age     0
# Fare    0
# dtype: int64

# %%
new_dataset.head(10)
# Out:
#     Age      Fare
# 0  38.0   71.2833
# 1  35.0   53.1000
# 2  54.0   51.8625
# 3   4.0   16.7000
# 4  58.0   26.5500
# 5  34.0   13.0000
# 6  28.0   35.5000
# 7  19.0  263.0000
# 8  49.0   76.7292
# 9  65.0   61.9792

# %%
dataset['Age'].mean()
# Out:
# 35.59245901639344

# %%
dataset.head(10)
# Out:
#     PassengerId Married  Survived  Pclass  \
# 1           2.0     Yes         1     1.0
# 3           4.0     Yes         1     1.0
# 6           7.0     Yes         0     1.0
# 10         11.0     Yes         1     3.0
# 11         12.0     Yes         1     1.0
# 21         22.0      No         1     2.0
# 23         24.0      No         1     1.0
# 27         28.0      No         0     1.0
# 52         53.0     NaN         1     1.0
# 54         55.0     NaN         0     1.0
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 1                                    Amartya Raj    male  23.0    1.0    0.0
# 3   Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0    0.0
# 6                        McCarthy, Mr. Timothy J    male  54.0    0.0    0.0
# 10               Sandstrom, Miss. Marguerite Rut  female   4.0    1.0    1.0
# 11                      Bonnell, Miss. Elizabeth  female  58.0    0.0    0.0
# 21                         Beesley, Mr. Lawrence    male  34.0    0.0    0.0
# 23                  Sloper, Mr. William Thompson    male  28.0    0.0    0.0
# 27                Fortune, Mr. Charles Alexander    male  19.0    3.0    2.0
# 52      Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0    1.0    0.0
# 54                Ostby, Mr. Engelhart Cornelius    male  65.0    0.0    1.0
#
#       Ticket      Fare        Cabin Embarked
# 1   PC 17599   71.2833          C85        C
# 3     113803   53.1000         C123        S
# 6      17463   51.8625          E46        S
# 10   PP 9549   16.7000           G6        S
# 11    113783   26.5500         C103        S
# 21    248698   13.0000          D56        S
# 23    113788   35.5000           A6        S
# 27     19950  263.0000  C23 C25 C27        S
# 52  PC 17572   76.7292          D33        C
# 54    113509   61.9792          B30        C

# %%
en_data = dataset[["Sex","Survived"]]

# %%
en_data
# Out:
#         Sex  Survived
# 1      male         1
# 3    female         1
# 6      male         0
# 10   female         1
# 11   female         1
# ..      ...       ...
# 871  female         1
# 872    male         0
# 879  female         1
# 887  female         1
# 889    male         1
#
# [183 rows x 2 columns]

# %%
pd.get_dummies(en_data)
# Out:
#      Survived  Sex_female  Sex_male
# 1           1       False      True
# 3           1        True     False
# 6           0       False      True
# 10          1        True     False
# 11          1        True     False
# ..        ...         ...       ...
# 871         1        True     False
# 872         0       False      True
# 879         1        True     False
# 887         1        True     False
# 889         1       False      True
#
# [183 rows x 3 columns]

# %%
plt.figure(figsize=(6,3))
sns.histplot(dataset["Age"],kde=True)
plt.title("Age Distributed")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize(6,3))
sns.countplot(data=data,x="Sex",hue="Sex")
plt.tilte("survival by gender")
